# %%
import streamlit as st
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import plot_confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score
from sklearn.preprocessing import MinMaxScaler
from catboost import Pool, CatBoostClassifier

def load():
    col_list = ['Pelvic_incidence',
                'Pelvic_tilt',
                'Lumbar_lordosis_angle',
                'Sacral_slope',
                'Pelvic_radius',
                'Degree_spondylolisthesis',
                'Pelvic_slope',
                'Direct_tilt',
                'Thoracic_slope',
                'Cervical_tilt',
                'Sacrum_angle',
                'Scoliosis_slope',
                'Class_att',
                'To_drop']
    data = pd.read_csv('/Users/ARSQy/Documents/This semester studies/ТМО/Лаба 6/Dataset_spine.csv', names=col_list, header=1, sep=",")
    data.drop('To_drop', axis=1, inplace=True)
    return data

# Готовим данные к ML
def preprocess_data(data):
    scale_cols = ['Pelvic_incidence',
                  'Pelvic_tilt',
                  'Lumbar_lordosis_angle',
                  'Sacral_slope',
                  'Pelvic_radius',
                  'Degree_spondylolisthesis',
                  'Pelvic_slope',
                  'Direct_tilt',
                  'Thoracic_slope',
                  'Cervical_tilt',
                  'Sacrum_angle',
                  'Scoliosis_slope']
    sc1 = MinMaxScaler()
    sc1_data = sc1.fit_transform(data[scale_cols])
    for i in range(len(scale_cols)):
        data[scale_cols[i]] = sc1_data[:, i]
    data['Class_att'] = data['Class_att'].map({'Abnormal': 1, 'Normal': 0})
    # Разделим данные на целевой столбец и признаки
    X = data.drop("Class_att", axis=1)
    Y = data["Class_att"]
    # С использованием метода train_test_split разделим выборку на обучающую и тестовую
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1)
    return X_train, X_test, Y_train, Y_test

# Отрисовка графика ROC_CURVE
def draw_roc_curve(y_true, y_score, ax, pos_label=1, average='micro'):
    fpr, tpr, thresholds = roc_curve(y_true, y_score,
                                     pos_label=pos_label)
    roc_auc_value = roc_auc_score(y_true, y_score, average=average)
    # plt.figure()
    lw = 2
    ax.plot(fpr, tpr, color='darkorange',
            lw=lw, label='ROC curve (area = %0.2f)' % roc_auc_value)
    ax.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_xlim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic')
    ax.legend(loc="lower right")

# Вывод метрик ML
def print_metrics(X_train, Y_train, X_test, Y_test, clf):
    clf.fit(X_train, Y_train)
    target = clf.predict(X_test)
    test_score = accuracy_score(Y_test, target)
    roc_res = clf.predict_proba(X_test)
    roc_auc = roc_auc_score(Y_test, roc_res[:, 1])
    f1_test_score = f1_score(Y_test, target)
    st.write(f"accuracy (точность): {test_score}")
    st.write(f"f1 метрика: {f1_test_score}")
    st.write(f"ROC AUC: {roc_auc}")
    fig1, ax1 = plt.subplots()
    draw_roc_curve(Y_test, roc_res[:, 1], ax1)
    st.pyplot(fig1)
    fig2, ax2 = plt.subplots(figsize=(10, 5))
    plot_confusion_matrix(clf, X_test, Y_test, ax=ax2, display_labels=['1', '0'], cmap = 'Purples', normalize='true')
    ax2.set(title="Confusion matrix")
    st.pyplot(fig2)
    return test_score

# Вывод кривой обучения
def plot_learning_curve(data_X, data_y, clf, name='accuracy', scoring='accuracy'):
    train_sizes, train_scores, test_scores = learning_curve(estimator=clf, scoring=scoring, X=data_X, y=data_y, train_sizes=np.linspace(0.1, 1.0, 10), cv=5)
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    fig = plt.figure(figsize=(7, 5))
    plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label=f'тренировочная {name}-мера')
    plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
    plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5,
             label=f'проверочная {name}-мера')
    plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
    plt.grid()
    plt.legend(loc='lower right')
    plt.xlabel('Число тренировочных образцов')
    plt.ylabel(f'{name}-мера')
    st.pyplot(fig)
    
if __name__ == '__main__':
    st.title('Метод градиентного бустинга')
    data = load()
    data_X_train, data_X_test, data_y_train, data_y_test = preprocess_data(data)

    # Будем показывать матрицу только по запросу, чттобы не тормозить процесс
    if st.checkbox('Показать корреляционную матрицу'):
        fig_corr, ax = plt.subplots(figsize=(20, 20))
        sns.heatmap(data.corr(), annot=True, cmap = 'Purples', fmt='.3f')
        st.pyplot(fig_corr)

    # Выбор гиперпараметров в сайдбаре
    st.sidebar.subheader('Гиперпараметры :')
    estimators = st.sidebar.slider('Количество деревьев: ', min_value=1, max_value=100, value=5, step=1)
    max_depth = st.sidebar.slider('Максимальная глубина', min_value=1, max_value=10, value=4, step=1)
    eval_metric = st.sidebar.selectbox('Оптимизируемая метрика:', ('Accuracy', 'F1', 'AUC'))

    # Вывод результатов
    translation_dict = {'Accuracy': 'accuracy', 'F1': 'f1', 'AUC': 'roc_auc'}
    gd = CatBoostClassifier(n_estimators=estimators, max_depth=max_depth, eval_metric=eval_metric, random_state=1)
    result = print_metrics(data_X_train, data_y_train, data_X_test, data_y_test, gd)
    data_X = pd.concat([data_X_train, data_X_test])
    data_y = pd.concat([data_y_train, data_y_test])
    plot_learning_curve(data_X, data_y, gd, name=translation_dict.get(eval_metric), scoring=translation_dict.get(eval_metric))
    # Показать данные
    if st.checkbox('Показать первые 10 строк датасета "Dataset_spine"'):
        st.write(data.head(10))
# Out:
# 2023-04-18 08:54:23.589
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# Learning rate set to 0.5
# 0:	learn: 0.8311688	total: 140ms	remaining: 562ms
# 1:	learn: 0.8441558	total: 141ms	remaining: 212ms
# 2:	learn: 0.8571429	total: 142ms	remaining: 94.5ms
# 3:	learn: 0.8744589	total: 142ms	remaining: 35.6ms
# 4:	learn: 0.8614719	total: 143ms	remaining: 0us
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Learning rate set to 0.269978
# 0:	learn: 1.0000000	total: 501us	remaining: 2ms
# 1:	learn: 0.9583333	total: 1.01ms	remaining: 1.51ms
# 2:	learn: 1.0000000	total: 1.39ms	remaining: 926us
# 3:	learn: 1.0000000	total: 1.78ms	remaining: 444us
# 4:	learn: 1.0000000	total: 2.28ms	remaining: 0us
# Learning rate set to 0.366178
# 0:	learn: 0.7959184	total: 491us	remaining: 1.97ms
# 1:	learn: 0.8775510	total: 814us	remaining: 1.22ms
# 2:	learn: 0.8979592	total: 1.1ms	remaining: 735us
# 3:	learn: 0.9387755	total: 1.41ms	remaining: 352us
# 4:	learn: 0.9387755	total: 1.72ms	remaining: 0us
# Learning rate set to 0.436657
# 0:	learn: 0.9054054	total: 616us	remaining: 2.47ms
# 1:	learn: 0.8783784	total: 1.04ms	remaining: 1.56ms
# 2:	learn: 0.8918919	total: 1.41ms	remaining: 943us
# 3:	learn: 0.9189189	total: 1.79ms	remaining: 447us
# 4:	learn: 0.9054054	total: 2.17ms	remaining: 0us
# Learning rate set to 0.492303
# 0:	learn: 0.8877551	total: 543us	remaining: 2.17ms
# 1:	learn: 0.8775510	total: 950us	remaining: 1.43ms
# 2:	learn: 0.8673469	total: 1.3ms	remaining: 866us
# 3:	learn: 0.8877551	total: 1.66ms	remaining: 414us
# 4:	learn: 0.8979592	total: 2.03ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8943089	total: 613us	remaining: 2.45ms
# 1:	learn: 0.8943089	total: 1.09ms	remaining: 1.64ms
# 2:	learn: 0.8943089	total: 1.46ms	remaining: 970us
# 3:	learn: 0.8861789	total: 1.83ms	remaining: 458us
# 4:	learn: 0.9024390	total: 2.19ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8175676	total: 543us	remaining: 2.17ms
# 1:	learn: 0.8310811	total: 957us	remaining: 1.44ms
# 2:	learn: 0.8716216	total: 1.33ms	remaining: 884us
# 3:	learn: 0.8851351	total: 1.71ms	remaining: 427us
# 4:	learn: 0.8986486	total: 2.13ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8197674	total: 631us	remaining: 2.53ms
# 1:	learn: 0.8720930	total: 1.12ms	remaining: 1.69ms
# 2:	learn: 0.8837209	total: 1.55ms	remaining: 1.03ms
# 3:	learn: 0.8837209	total: 1.96ms	remaining: 489us
# 4:	learn: 0.8953488	total: 2.33ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8375635	total: 723us	remaining: 2.89ms
# 1:	learn: 0.8426396	total: 1.22ms	remaining: 1.83ms
# 2:	learn: 0.8730964	total: 1.68ms	remaining: 1.12ms
# 3:	learn: 0.8934010	total: 2.14ms	remaining: 534us
# 4:	learn: 0.9187817	total: 2.57ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8783784	total: 752us	remaining: 3.01ms
# 1:	learn: 0.8828829	total: 1.35ms	remaining: 2.03ms
# 2:	learn: 0.8918919	total: 1.83ms	remaining: 1.22ms
# 3:	learn: 0.9009009	total: 2.27ms	remaining: 568us
# 4:	learn: 0.9144144	total: 2.69ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8704453	total: 896us	remaining: 3.58ms
# 1:	learn: 0.8825911	total: 1.61ms	remaining: 2.41ms
# 2:	learn: 0.8906883	total: 2.31ms	remaining: 1.54ms
# 3:	learn: 0.9028340	total: 2.99ms	remaining: 746us
# 4:	learn: 0.9068826	total: 3.64ms	remaining: 0us
# Learning rate set to 0.269978
# 0:	learn: 0.9583333	total: 457us	remaining: 1.83ms
# 1:	learn: 0.9583333	total: 856us	remaining: 1.28ms
# 2:	learn: 0.9583333	total: 1.21ms	remaining: 808us
# 3:	learn: 0.9583333	total: 1.54ms	remaining: 384us
# 4:	learn: 0.9166667	total: 1.84ms	remaining: 0us
# Learning rate set to 0.366178
# 0:	learn: 0.8571429	total: 422us	remaining: 1.69ms
# 1:	learn: 0.9183673	total: 809us	remaining: 1.21ms
# 2:	learn: 0.9795918	total: 1.26ms	remaining: 843us
# 3:	learn: 0.9387755	total: 1.58ms	remaining: 394us
# 4:	learn: 0.9795918	total: 1.9ms	remaining: 0us
# Learning rate set to 0.436657
# 0:	learn: 0.8108108	total: 479us	remaining: 1.92ms
# 1:	learn: 0.8108108	total: 857us	remaining: 1.29ms
# 2:	learn: 0.8783784	total: 1.23ms	remaining: 822us
# 3:	learn: 0.9054054	total: 1.58ms	remaining: 394us
# 4:	learn: 0.9189189	total: 1.94ms	remaining: 0us
# Learning rate set to 0.492303
# 0:	learn: 0.7653061	total: 589us	remaining: 2.36ms
# 1:	learn: 0.8571429	total: 1.24ms	remaining: 1.86ms
# 2:	learn: 0.8469388	total: 1.58ms	remaining: 1.05ms
# 3:	learn: 0.8673469	total: 1.93ms	remaining: 482us
# 4:	learn: 0.8877551	total: 2.3ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8130081	total: 610us	remaining: 2.44ms
# 1:	learn: 0.8130081	total: 1ms	remaining: 1.5ms
# 2:	learn: 0.8130081	total: 1.4ms	remaining: 934us
# 3:	learn: 0.8617886	total: 1.8ms	remaining: 449us
# 4:	learn: 0.8617886	total: 2.22ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.7972973	total: 692us	remaining: 2.77ms
# 1:	learn: 0.7905405	total: 1.17ms	remaining: 1.75ms
# 2:	learn: 0.8378378	total: 1.77ms	remaining: 1.18ms
# 3:	learn: 0.8310811	total: 2.3ms	remaining: 574us
# 4:	learn: 0.8716216	total: 2.71ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8023256	total: 743us	remaining: 2.97ms
# 1:	learn: 0.8139535	total: 1.26ms	remaining: 1.9ms
# 2:	learn: 0.8430233	total: 1.68ms	remaining: 1.12ms
# 3:	learn: 0.8313953	total: 2.14ms	remaining: 535us
# 4:	learn: 0.8720930	total: 2.54ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8172589	total: 658us	remaining: 2.63ms
# 1:	learn: 0.8071066	total: 1.12ms	remaining: 1.69ms
# 2:	learn: 0.8324873	total: 1.64ms	remaining: 1.09ms
# 3:	learn: 0.8629442	total: 2.2ms	remaining: 549us
# 4:	learn: 0.8629442	total: 2.79ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8288288	total: 1.07ms	remaining: 4.27ms
# 1:	learn: 0.8198198	total: 1.78ms	remaining: 2.67ms
# 2:	learn: 0.8558559	total: 2.24ms	remaining: 1.49ms
# 3:	learn: 0.8693694	total: 2.77ms	remaining: 692us
# 4:	learn: 0.8693694	total: 3.26ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8421053	total: 848us	remaining: 3.4ms
# 1:	learn: 0.8542510	total: 1.55ms	remaining: 2.33ms
# 2:	learn: 0.8461538	total: 2.27ms	remaining: 1.52ms
# 3:	learn: 0.8866397	total: 3.04ms	remaining: 760us
# 4:	learn: 0.8906883	total: 3.85ms	remaining: 0us
# Learning rate set to 0.269978
# 0:	learn: 0.9583333	total: 438us	remaining: 1.75ms
# 1:	learn: 0.9583333	total: 819us	remaining: 1.23ms
# 2:	learn: 0.9583333	total: 1.11ms	remaining: 743us
# 3:	learn: 0.9583333	total: 1.39ms	remaining: 346us
# 4:	learn: 0.9166667	total: 1.67ms	remaining: 0us
# Learning rate set to 0.366178
# 0:	learn: 0.8571429	total: 857us	remaining: 3.43ms
# 1:	learn: 0.9183673	total: 1.44ms	remaining: 2.16ms
# 2:	learn: 0.9795918	total: 2ms	remaining: 1.33ms
# 3:	learn: 0.9387755	total: 2.48ms	remaining: 621us
# 4:	learn: 0.9795918	total: 2.85ms	remaining: 0us
# Learning rate set to 0.436657
# 0:	learn: 0.8243243	total: 461us	remaining: 1.85ms
# 1:	learn: 0.8108108	total: 892us	remaining: 1.34ms
# 2:	learn: 0.8378378	total: 1.44ms	remaining: 958us
# 3:	learn: 0.8513514	total: 1.9ms	remaining: 474us
# 4:	learn: 0.8648649	total: 2.23ms	remaining: 0us
# Learning rate set to 0.492303
# 0:	learn: 0.8061224	total: 551us	remaining: 2.2ms
# 1:	learn: 0.8367347	total: 1.11ms	remaining: 1.67ms
# 2:	learn: 0.8571429	total: 1.67ms	remaining: 1.11ms
# 3:	learn: 0.8775510	total: 2.16ms	remaining: 540us
# 4:	learn: 0.8673469	total: 2.65ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8699187	total: 614us	remaining: 2.46ms
# 1:	learn: 0.8617886	total: 1.14ms	remaining: 1.7ms
# 2:	learn: 0.8780488	total: 1.52ms	remaining: 1.01ms
# 3:	learn: 0.8780488	total: 1.88ms	remaining: 470us
# 4:	learn: 0.9105691	total: 2.25ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8175676	total: 673us	remaining: 2.69ms
# 1:	learn: 0.8378378	total: 1.23ms	remaining: 1.84ms
# 2:	learn: 0.8310811	total: 1.62ms	remaining: 1.08ms
# 3:	learn: 0.8783784	total: 2.04ms	remaining: 511us
# 4:	learn: 0.8648649	total: 2.69ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8488372	total: 673us	remaining: 2.69ms
# 1:	learn: 0.8546512	total: 1.24ms	remaining: 1.86ms
# 2:	learn: 0.8662791	total: 1.63ms	remaining: 1.09ms
# 3:	learn: 0.8837209	total: 2.08ms	remaining: 519us
# 4:	learn: 0.8662791	total: 2.51ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8375635	total: 712us	remaining: 2.85ms
# 1:	learn: 0.8680203	total: 1.19ms	remaining: 1.78ms
# 2:	learn: 0.8781726	total: 1.61ms	remaining: 1.07ms
# 3:	learn: 0.8984772	total: 2.02ms	remaining: 506us
# 4:	learn: 0.9086294	total: 2.46ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8423423	total: 946us	remaining: 3.79ms
# 1:	learn: 0.8513514	total: 1.6ms	remaining: 2.4ms
# 2:	learn: 0.8513514	total: 2.13ms	remaining: 1.42ms
# 3:	learn: 0.8603604	total: 2.56ms	remaining: 640us
# 4:	learn: 0.8693694	total: 3.05ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8502024	total: 840us	remaining: 3.36ms
# 1:	learn: 0.8623482	total: 1.31ms	remaining: 1.97ms
# 2:	learn: 0.8704453	total: 1.76ms	remaining: 1.18ms
# 3:	learn: 0.8947368	total: 2.25ms	remaining: 562us
# 4:	learn: 0.8825911	total: 2.71ms	remaining: 0us
# Learning rate set to 0.269978
# 0:	learn: 0.9583333	total: 475us	remaining: 1.9ms
# 1:	learn: 0.9583333	total: 915us	remaining: 1.37ms
# 2:	learn: 0.9583333	total: 1.24ms	remaining: 824us
# 3:	learn: 0.9583333	total: 1.57ms	remaining: 392us
# 4:	learn: 0.9166667	total: 1.91ms	remaining: 0us
# Learning rate set to 0.366178
# 0:	learn: 0.8571429	total: 419us	remaining: 1.68ms
# 1:	learn: 0.9183673	total: 987us	remaining: 1.48ms
# 2:	learn: 0.9795918	total: 1.34ms	remaining: 891us
# 3:	learn: 0.9387755	total: 1.65ms	remaining: 413us
# 4:	learn: 0.9795918	total: 1.98ms	remaining: 0us
# Learning rate set to 0.436657
# 0:	learn: 0.8243243	total: 494us	remaining: 1.98ms
# 1:	learn: 0.8108108	total: 897us	remaining: 1.35ms
# 2:	learn: 0.8378378	total: 1.34ms	remaining: 890us
# 3:	learn: 0.8513514	total: 1.77ms	remaining: 441us
# 4:	learn: 0.8648649	total: 2.26ms	remaining: 0us
# Learning rate set to 0.492303
# 0:	learn: 0.8061224	total: 518us	remaining: 2.08ms
# 1:	learn: 0.8367347	total: 1.11ms	remaining: 1.66ms
# 2:	learn: 0.8571429	total: 1.65ms	remaining: 1.1ms
# 3:	learn: 0.8775510	total: 2.16ms	remaining: 539us
# 4:	learn: 0.8673469	total: 2.63ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8699187	total: 722us	remaining: 2.89ms
# 1:	learn: 0.8617886	total: 1.25ms	remaining: 1.88ms
# 2:	learn: 0.8780488	total: 1.69ms	remaining: 1.13ms
# 3:	learn: 0.8780488	total: 2.14ms	remaining: 534us
# 4:	learn: 0.9105691	total: 2.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8445946	total: 563us	remaining: 2.25ms
# 1:	learn: 0.8986486	total: 1.01ms	remaining: 1.52ms
# 2:	learn: 0.8378378	total: 1.39ms	remaining: 923us
# 3:	learn: 0.8445946	total: 1.77ms	remaining: 443us
# 4:	learn: 0.8716216	total: 2.17ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8139535	total: 734us	remaining: 2.94ms
# 1:	learn: 0.7965116	total: 1.2ms	remaining: 1.8ms
# 2:	learn: 0.8546512	total: 1.64ms	remaining: 1.09ms
# 3:	learn: 0.8779070	total: 2.03ms	remaining: 507us
# 4:	learn: 0.8895349	total: 2.45ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8426396	total: 763us	remaining: 3.05ms
# 1:	learn: 0.8426396	total: 1.37ms	remaining: 2.06ms
# 2:	learn: 0.8477157	total: 1.9ms	remaining: 1.26ms
# 3:	learn: 0.8578680	total: 2.35ms	remaining: 586us
# 4:	learn: 0.8527919	total: 2.92ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8603604	total: 898us	remaining: 3.59ms
# 1:	learn: 0.8558559	total: 1.68ms	remaining: 2.52ms
# 2:	learn: 0.8873874	total: 2.39ms	remaining: 1.59ms
# 3:	learn: 0.8918919	total: 2.89ms	remaining: 722us
# 4:	learn: 0.8963964	total: 3.53ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8663968	total: 776us	remaining: 3.1ms
# 1:	learn: 0.8582996	total: 1.46ms	remaining: 2.19ms
# 2:	learn: 0.8785425	total: 2.03ms	remaining: 1.35ms
# 3:	learn: 0.8825911	total: 2.52ms	remaining: 629us
# 4:	learn: 0.8866397	total: 2.99ms	remaining: 0us
# Learning rate set to 0.269978
# 0:	learn: 0.9583333	total: 436us	remaining: 1.75ms
# 1:	learn: 0.9583333	total: 776us	remaining: 1.17ms
# 2:	learn: 0.9583333	total: 1.13ms	remaining: 754us
# 3:	learn: 0.9583333	total: 1.45ms	remaining: 361us
# 4:	learn: 0.9166667	total: 1.74ms	remaining: 0us
# Learning rate set to 0.366178
# 0:	learn: 0.8571429	total: 454us	remaining: 1.82ms
# 1:	learn: 0.9183673	total: 851us	remaining: 1.28ms
# 2:	learn: 0.9795918	total: 1.21ms	remaining: 803us
# 3:	learn: 0.9387755	total: 1.62ms	remaining: 404us
# 4:	learn: 0.9795918	total: 1.96ms	remaining: 0us
# Learning rate set to 0.436657
# 0:	learn: 0.8243243	total: 628us	remaining: 2.51ms
# 1:	learn: 0.8108108	total: 1.18ms	remaining: 1.77ms
# 2:	learn: 0.8378378	total: 1.55ms	remaining: 1.03ms
# 3:	learn: 0.8513514	total: 1.89ms	remaining: 472us
# 4:	learn: 0.8648649	total: 2.2ms	remaining: 0us
# Learning rate set to 0.492303
# 0:	learn: 0.8061224	total: 614us	remaining: 2.46ms
# 1:	learn: 0.8367347	total: 1.07ms	remaining: 1.6ms
# 2:	learn: 0.8571429	total: 1.51ms	remaining: 1ms
# 3:	learn: 0.8775510	total: 1.9ms	remaining: 474us
# 4:	learn: 0.8673469	total: 2.34ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8699187	total: 517us	remaining: 2.07ms
# 1:	learn: 0.8617886	total: 912us	remaining: 1.37ms
# 2:	learn: 0.8780488	total: 1.28ms	remaining: 853us
# 3:	learn: 0.8780488	total: 1.67ms	remaining: 418us
# 4:	learn: 0.9105691	total: 2.04ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8445946	total: 796us	remaining: 3.18ms
# 1:	learn: 0.8986486	total: 1.22ms	remaining: 1.82ms
# 2:	learn: 0.8378378	total: 1.66ms	remaining: 1.11ms
# 3:	learn: 0.8445946	total: 2.06ms	remaining: 514us
# 4:	learn: 0.8716216	total: 2.46ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8139535	total: 844us	remaining: 3.38ms
# 1:	learn: 0.7965116	total: 1.32ms	remaining: 1.99ms
# 2:	learn: 0.8546512	total: 1.77ms	remaining: 1.18ms
# 3:	learn: 0.8779070	total: 2.16ms	remaining: 540us
# 4:	learn: 0.8895349	total: 2.56ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8071066	total: 895us	remaining: 3.58ms
# 1:	learn: 0.8121827	total: 1.58ms	remaining: 2.37ms
# 2:	learn: 0.8324873	total: 2.28ms	remaining: 1.52ms
# 3:	learn: 0.8375635	total: 2.89ms	remaining: 723us
# 4:	learn: 0.8680203	total: 3.49ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8108108	total: 1.07ms	remaining: 4.29ms
# 1:	learn: 0.8108108	total: 1.75ms	remaining: 2.63ms
# 2:	learn: 0.8378378	total: 2.22ms	remaining: 1.48ms
# 3:	learn: 0.8558559	total: 2.67ms	remaining: 666us
# 4:	learn: 0.8468468	total: 3.11ms	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.8137652	total: 884us	remaining: 3.54ms
# 1:	learn: 0.8056680	total: 1.36ms	remaining: 2.04ms
# 2:	learn: 0.8178138	total: 1.83ms	remaining: 1.22ms
# 3:	learn: 0.8947368	total: 2.29ms	remaining: 572us
# 4:	learn: 0.8785425	total: 2.75ms	remaining: 0us

# %%
streamlit run l6.ipynb
# Out:
#   File "C:\Users\ARSQy\AppData\Local\Temp\ipykernel_15028\138438065.py", line 1
#     streamlit run l6.ipynb
#               ^
# SyntaxError: invalid syntax
